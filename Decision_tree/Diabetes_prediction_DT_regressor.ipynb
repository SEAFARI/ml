# %% [markdown]
# ## Diabetes Predictions

# %%
from sklearn.datasets import load_diabetes

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
diabetes = load_diabetes()

# %%
df = pd.DataFrame(data=diabetes.data,columns=diabetes.feature_names)

# %%
df.head()
# Out:
#         age       sex       bmi  ...        s4        s5        s6
# 0  0.038076  0.050680  0.061696  ... -0.002592  0.019907 -0.017646
# 1 -0.001882 -0.044642 -0.051474  ... -0.039493 -0.068332 -0.092204
# 2  0.085299  0.050680  0.044451  ... -0.002592  0.002861 -0.025930
# 3 -0.089063 -0.044642 -0.011595  ...  0.034309  0.022688 -0.009362
# 4  0.005383 -0.044642 -0.036385  ... -0.002592 -0.031988 -0.046641
#
# [5 rows x 10 columns]

# %%
df['target'] = diabetes.target

# %%
df.head()
# Out:
#         age       sex       bmi        bp  ...        s4        s5        s6  target
# 0  0.038076  0.050680  0.061696  0.021872  ... -0.002592  0.019907 -0.017646   151.0
# 1 -0.001882 -0.044642 -0.051474 -0.026328  ... -0.039493 -0.068332 -0.092204    75.0
# 2  0.085299  0.050680  0.044451 -0.005670  ... -0.002592  0.002861 -0.025930   141.0
# 3 -0.089063 -0.044642 -0.011595 -0.036656  ...  0.034309  0.022688 -0.009362   206.0
# 4  0.005383 -0.044642 -0.036385  0.021872  ... -0.002592 -0.031988 -0.046641   135.0
#
# [5 rows x 11 columns]

# %%
X = df.drop('target',axis=1)
Y = df['target']

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.33,random_state=42)

# %%
X_train.head()
# Out:
#           age       sex       bmi  ...        s4        s5        s6
# 231  0.009016 -0.044642 -0.030996  ... -0.002592  0.009434  0.011349
# 325 -0.001882 -0.044642  0.054152  ...  0.084863  0.084492  0.048628
# 193  0.009016  0.050680 -0.005128  ...  0.071210  0.039542  0.019633
# 109  0.038076  0.050680 -0.009439  ...  0.050176 -0.025953  0.106617
# 195  0.027178  0.050680  0.025051  ...  0.034309  0.007838  0.023775
#
# [5 rows x 10 columns]

# %%
X_train.corr()
# Out:
#           age       sex       bmi  ...        s4        s5        s6
# age  1.000000  0.158365  0.154118  ...  0.167114  0.265242  0.271433
# sex  0.158365  1.000000  0.064689  ...  0.339617  0.129306  0.174451
# bmi  0.154118  0.064689  1.000000  ...  0.434438  0.439079  0.390869
# bp   0.296175  0.179566  0.377067  ...  0.212675  0.353409  0.386687
# s1   0.256847  0.039423  0.237922  ...  0.547016  0.522204  0.315614
# s2   0.199423  0.134719  0.255167  ...  0.646648  0.294901  0.282576
# s3  -0.027358 -0.350479 -0.378082  ... -0.729197 -0.373460 -0.280956
# s4   0.167114  0.339617  0.434438  ...  1.000000  0.619194  0.413076
# s5   0.265242  0.129306  0.439079  ...  0.619194  1.000000  0.456700
# s6   0.271433  0.174451  0.390869  ...  0.413076  0.456700  1.000000
#
# [10 rows x 10 columns]

# %%
plt.figure(figsize=(15,10))
sns.heatmap(X_train.corr(),annot=True)
# Out:
# <Axes: >
